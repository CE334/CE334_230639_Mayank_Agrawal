# %% [markdown]
# <a href="https://colab.research.google.com/github/CE334/CE334_230639_Mayank_Agrawal/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Workd")
# Out:
# Hello Workd

# %%
print(344)
# Out:
# 344
